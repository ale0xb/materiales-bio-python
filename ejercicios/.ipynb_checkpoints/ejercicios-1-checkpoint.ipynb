# %% [markdown]
# ## Ejercicio 1: Reemplaza
# Declara dos variables (var_1 y var_2) que recojan la entrada de teclado del usuario.
# En las cadenas resultantes realiza las siguientes operaciones:
# 1. Reemplaza todas las apariciones de "a" por "e" e imprime el resultado.
# 2. Cuenta el número de caracteres de cada cadena e imprime el resultado.
# 3. Convierta la cadena a mayúsculas e imprime el resultado.

# %% [markdown]
# ## Ejercicio 2: PimPam
# Escribe el código de un bucle que imprima por pantalla los números del 1 al 20. Para aquellos números que sean múltiplos de tres, imprime "Pim" (Sin las comillas) en vez del número. Para los múltiplos de cinco, imprime "Pam". Para aquellos números que sean a la vez múltiplos de tres y de cinco imprime "PimPam".

# %% [markdown]
# ## Ejercicio 3:
# Esta cadena es el origen de replicación (oriC) del genoma de la bacteria Vibrio Cholerae:

# %%
vc_oriC = '...'

# %% [markdown]
# **Pregunta**
# ¿Qué longitud tiene el origen de la replicación?

# %% [markdown]
# Y este es el genoma del Vibrio Cholerae. No te preocupes si no entiendes lo que ocurre: Básicamente lo que estoy haciendo es abrir un fichero que contiene la secuencia (más sobre esto en las próximas clases)

# %%
vc_oriC_sec = open("../data/vibrio_cholerae.txt","r+").read()

# %%
#Cadena muuuuy larga
#Comprueba su longitud!
vibrio
# Out:
# '...\n'

# %% [markdown]
# **Preguntas:**
# 1. ¿En qué posición comienza el origen de la replicación en el Vibrio Cholerae?
# 2. ¿Y en qué porcentaje en relación a la longitud total de la secuencia?
# 3. ¿Cuáles son las frequencia absolutas y relativas de bases {A, C, T, G} en oriC? ¿Y en todo el genoma?
#     3.1 ¿Puedes escribir una función? Devuelve los resultados e imprímelos **fuera** de la función.
#     3.2 Imprime tus resultados por pantalla
# 4. Puedes adaptar la función (crea otra aparte) para que haga lo mismo que en el anterior caso, pero para combinaciones de nucléotidos de longitud n=2 {AC, AT, AG, CT, CG, TG}?
